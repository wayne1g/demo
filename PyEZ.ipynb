# %%
from pprint import pprint
from jnpr.junos import Device
from datetime import datetime
from jnpr.junos import exception as EzErrors
from lxml import etree
import os

# %%
from jnpr.junos.utils.config import Config

dev = Device('core1', user='lab', password='lab123', timeout = 10)
dev.open()

# data = dev.rpc.get_config(filter_xml="system/services", options={'format':'xml'})
data = dev.rpc.get_config(filter_xml="system/services", options={'format':'text'})
print(etree.tostring(data, encoding='unicode'))
# Out:
# <configuration-text>
# ## Last changed: 2017-11-14 09:53:29 HKT
# system {
#     services {
#         ssh;
#         netconf {
#             ssh;
#             traceoptions {
#                 file test.log;
#             }
#         }
#     }
# }
# </configuration-text>

# %%
with Config(dev, mode='private') as cu:  
    cu.load('set system services netconf traceoptions file test.log', format='set')
    cu.pdiff()
    cu.commit()
# Out:
# [edit system services netconf]
# +     traceoptions {
# +         file test.log;
# +     }

# %% [markdown]
# with Config(dev, mode='private') as cu:
#     cu.load('set interfaces ge-0/0/0 unit 0 family inet address 1.1.1.100/24', format='set',
#             merge=True)
#     cu.pdiff()
#     cu.commit()

# %%
# %more ge000.conf
'''
interfaces {
replace:
    ge-0/0/0 {
        unit 0 {
            family inet {
                address 222.2.2.2/24;
            }
            family mpls;
        }
    }
}
'''
# Out:
# '\ninterfaces {\nreplace:\n    ge-0/0/0 {\n        unit 0 {\n            family inet {\n                address 192.168.12.1/24;\n            }\n            family mpls;\n        }\n    }\n}\n'

# %%
conf_file = "./ge000.conf"

with Config(dev, mode='private') as cu:  
#     cu.load('set interfaces ge-0/0/0 unit 0 family inet address 222.0.0.1/24', format='set', 
#             merge=True)
    cu.load(path=conf_file, merge=True)
    cu.pdiff()
    cu.commit()
# Out:
# [edit interfaces ge-0/0/0 unit 0 family inet]
#         address 192.168.12.1/24 { ... }
# +       address 222.2.2.2/24;

# %%
with Config(dev, mode='private') as cu:  
#     cu.load('set interfaces ge-0/0/0 unit 0 family inet address 222.0.0.1/24', format='set', 
#             merge=True)
    cu.load(path=conf_file)
    cu.pdiff()
    cu.commit()
# Out:
# None

# %%
conf_file = "./ge000_original.conf"

with Config(dev, mode='private') as cu:  
#     cu.load('set interfaces ge-0/0/0 unit 0 family inet address 222.0.0.1/24', format='set', 
#             merge=True)
    cu.load(path=conf_file, merge=True)
    cu.pdiff()
    cu.commit()
# Out:
# None

# %%
conf_file = "./ge000_original.conf"

with Config(dev, mode='private') as cu:  
#     cu.load('set interfaces ge-0/0/0 unit 0 family inet address 222.0.0.1/24', format='set', 
#             merge=True)
    cu.load(path=conf_file)
    cu.pdiff()
    cu.commit(comment='Configuring ge-0/0/0 interface')
# Out:
# [edit interfaces ge-0/0/0 unit 0 family inet]
# -       address 222.2.2.2/24;

# %%
with Config(dev, mode='private') as cu:
    diff = cu.diff(rb_id=1)
    print(diff)
# Out:
# [edit interfaces ge-0/0/0 unit 0 family inet]
# -       address 222.2.2.2/24;

# %%
dev.close()

# %%
# Putting things all together
from jnpr.junos.exception import ConnectError
from jnpr.junos.exception import LockError
from jnpr.junos.exception import RpcError
from jnpr.junos.exception import CommitError
from jnpr.junos.exception import UnlockError

# %%
dev = Device('core1', user='lab', password='lab123', timeout = 10)

# open a connection with the device and start a NETCONF session
try:
    dev.open()
except ConnectError as err:
    print ("Cannot connect to device: {0}".format(err))

# %%
# Set up config object
cu = Config(dev)

# %%
# Lock the configuration
print ("Locking the configuration")
try:
    cu.lock()
except LockError as err:
    print ("Unable to lock configuration: {0}".format(err))
    dev.close()
# Out:
# Locking the configuration

# %%
rback = 1 
try:
    diff = cu.diff(rb_id=rback)
    print(diff)
    print("Rolling back the configuration by %d commit" % rback)
    cu.rollback(rb_id=1)
    print ("Committing the configuration")
    cu.commit()
except CommitError as err:
    print ("Error: Unable to commit configuration: {0}".format(err))
except RpcError as err:
    print ("Unable to rollback configuration changes: {0}".format(err))
# Out:
# [edit interfaces ge-0/0/0 unit 0 family inet]
# -       address 222.2.2.2/24;
#
# Rolling back the configuration by 1 commit
# Committing the configuration

# %%
finally:
    print ("Unlocking the configuration")
    try:
        cu.unlock()
    except UnlockError as err:
        print ("Unable to unlock configuration: {0}".format(err))
    dev.close()

# %%
print(dev.display_xml_rpc('show route', format='text'))
print(dev.display_xml_rpc('show version', format='text'))
# Out:
# <get-route-information>
# </get-route-information>
#
# <get-software-information>
# </get-software-information>

# %%
#invoke the RPC equivalent to "show route"
rt = dev.rpc.get_route_information()
pprint(etree.tostring(rt, encoding='unicode', pretty_print=True))

#invoke the RPC equivalent to "show version"
sw = dev.rpc.get_software_information()
print(etree.tostring(sw, encoding='unicode',  pretty_print=True))
# Out:
# ('<route-information>\n'
#  '<!-- keepalive -->\n'
#  '<route-table>\n'
#  '<table-name>inet.0</table-name>\n'
#  '<destination-count>11</destination-count>\n'
#  '<total-route-count>11</total-route-count>\n'
#  '<active-route-count>11</active-route-count>\n'
#  '<holddown-route-count>0</holddown-route-count>\n'
#  '<hidden-route-count>0</hidden-route-count>\n'
#  '<rt style="brief">\n'
#  '<rt-destination>0.0.0.0/0</rt-destination>\n'
#  '<rt-entry>\n'
#  '<active-tag>*</active-tag>\n'
#  '<current-active/>\n'
#  '<last-active/>\n'
#  '<protocol-name>Static</protocol-name>\n'
#  '<preference>5</preference>\n'
#  '<age seconds="40598">11:16:38</age>\n'
#  '<nh>\n'
#  '<selected-next-hop/>\n'
#  '<to>172.17.0.1</to>\n'
#  '<via>fxp0.0</via>\n'
#  '</nh>\n'
#  '</rt-entry>\n'
#  '</rt>\n'
#  '<rt style="brief">\n'
#  '<rt-destination>1.1.1.1/32</rt-destination>\n'
#  '<rt-entry>\n'
#  '<active-tag>*</active-tag>\n'
#  '<current-active/>\n'
#  '<last-active/>\n'
#  '<protocol-name>Direct</protocol-name>\n'
#  '<preference>0</preference>\n'
#  '<age seconds="40599">11:16:39</age>\n'
#  '<nh>\n'
#  '<selected-next-hop/>\n'
#  '<via>lo0.0</via>\n'
#  '</nh>\n'
#  '</rt-entry>\n'
#  '</rt>\n'
#  '<rt style="brief">\n'
#  '<rt-destination>2.2.2.2/32</rt-destination>\n'
#  '<rt-entry>\n'
#  '<active-tag>*</active-tag>\n'
#  '<current-active/>\n'
#  '<last-active/>\n'
#  '<protocol-name>OSPF</protocol-name>\n'
#  '<preference>10</preference>\n'
#  '<age seconds="2656">00:44:16</age>\n'
#  '<metric>1</metric>\n'
#  '<nh>\n'
#  '<selected-next-hop/>\n'
#  '<to>192.168.12.2</to>\n'
#  '<via>ge-0/0/0.0</via>\n'
#  '</nh>\n'
#  '</rt-entry>\n'
#  '</rt>\n'
#  '<rt style="brief">\n'
#  '<rt-destination>172.17.0.0/24</rt-destination>\n'
#  '<rt-entry>\n'
#  '<active-tag>*</active-tag>\n'
#  '<current-active/>\n'
#  '<last-active/>\n'
#  '<protocol-name>Direct</protocol-name>\n'
#  '<preference>0</preference>\n'
#  '<age seconds="40599">11:16:39</age>\n'
#  '<nh>\n'
#  '<selected-next-hop/>\n'
#  '<via>fxp0.0</via>\n'
#  '</nh>\n'
#  '</rt-entry>\n'
#  '</rt>\n'
#  '<rt style="brief">\n'
#  '<rt-destination>172.17.0.101/32</rt-destination>\n'
#  '<rt-entry>\n'
#  '<active-tag>*</active-tag>\n'
#  '<current-active/>\n'
#  '<last-active/>\n'
#  '<protocol-name>Local</protocol-name>\n'
#  '<preference>0</preference>\n'
#  '<age seconds="40599">11:16:39</age>\n'
#  '<nh-type>Local</nh-type>\n'
#  '<nh>\n'
#  '<nh-local-interface>fxp0.0</nh-local-interface>\n'
#  '</nh>\n'
#  '</rt-entry>\n'
#  '</rt>\n'
#  '<rt style="brief">\n'
#  '<rt-destination>192.168.12.0/24</rt-destination>\n'
#  '<rt-entry>\n'
#  '<active-tag>*</active-tag>\n'
#  '<current-active/>\n'
#  '<last-active/>\n'
#  '<protocol-name>Direct</protocol-name>\n'
#  '<preference>0</preference>\n'
#  '<age seconds="2656">00:44:16</age>\n'
#  '<nh>\n'
#  '<selected-next-hop/>\n'
#  '<via>ge-0/0/0.0</via>\n'
#  '</nh>\n'
#  '</rt-entry>\n'
#  '</rt>\n'
#  '<rt style="brief">\n'
#  '<rt-destination>192.168.12.1/32</rt-destination>\n'
#  '<rt-entry>\n'
#  '<active-tag>*</active-tag>\n'
#  '<current-active/>\n'
#  '<last-active/>\n'
#  '<protocol-name>Local</protocol-name>\n'
#  '<preference>0</preference>\n'
#  '<age seconds="2656">00:44:16</age>\n'
#  '<nh-type>Local</nh-type>\n'
#  '<nh>\n'
#  '<nh-local-interface>ge-0/0/0.0</nh-local-interface>\n'
#  '</nh>\n'
#  '</rt-entry>\n'
#  '</rt>\n'
#  '<rt style="brief">\n'
#  '<rt-destination>222.2.2.0/24</rt-destination>\n'
#  '<rt-entry>\n'
#  '<active-tag>*</active-tag>\n'
#  '<current-active/>\n'
#  '<last-active/>\n'
#  '<protocol-name>Direct</protocol-name>\n'
#  '<preference>0</preference>\n'
#  '<age seconds="1787">00:29:47</age>\n'
#  '<nh>\n'
#  '<selected-next-hop/>\n'
#  '<via>ge-0/0/0.0</via>\n'
#  '</nh>\n'
#  '</rt-entry>\n'
#  '</rt>\n'
#  '<rt style="brief">\n'
#  '<rt-destination>222.2.2.2/32</rt-destination>\n'
#  '<rt-entry>\n'
#  '<active-tag>*</active-tag>\n'
#  '<current-active/>\n'
#  '<last-active/>\n'
#  '<protocol-name>Local</protocol-name>\n'
#  '<preference>0</preference>\n'
#  '<age seconds="1787">00:29:47</age>\n'
#  '<nh-type>Local</nh-type>\n'
#  '<nh>\n'
#  '<nh-local-interface>ge-0/0/0.0</nh-local-interface>\n'
#  '</nh>\n'
#  '</rt-entry>\n'
#  '</rt>\n'
#  '<rt style="brief">\n'
#  '<rt-destination>224.0.0.2/32</rt-destination>\n'
#  '<rt-entry>\n'
#  '<active-tag>*</active-tag>\n'
#  '<current-active/>\n'
#  '<last-active/>\n'
#  '<protocol-name>LDP</protocol-name>\n'
#  '<preference>9</preference>\n'
#  '<age seconds="40488">11:14:48</age>\n'
#  '<metric>1</metric>\n'
#  '<nh-type>MultiRecv</nh-type>\n'
#  '</rt-entry>\n'
#  '</rt>\n'
#  '<rt style="brief">\n'
#  '<rt-destination>224.0.0.5/32</rt-destination>\n'
#  '<rt-entry>\n'
#  '<active-tag>*</active-tag>\n'
#  '<current-active/>\n'
#  '<last-active/>\n'
#  '<protocol-name>OSPF</protocol-name>\n'
#  '<preference>10</preference>\n'
#  '<age seconds="40600">11:16:40</age>\n'
#  '<metric>1</metric>\n'
#  '<nh-type>MultiRecv</nh-type>\n'
#  '</rt-entry>\n'
#  '</rt>\n'
#  '</route-table>\n'
#  '<route-table>\n'
#  '<table-name>inet.3</table-name>\n'
#  '<destination-count>1</destination-count>\n'
#  '<total-route-count>1</total-route-count>\n'
#  '<active-route-count>1</active-route-count>\n'
#  '<holddown-route-count>0</holddown-route-count>\n'
#  '<hidden-route-count>0</hidden-route-count>\n'
#  '<rt style="brief">\n'
#  '<rt-destination>2.2.2.2/32</rt-destination>\n'
#  '<rt-entry>\n'
#  '<active-tag>*</active-tag>\n'
#  '<current-active/>\n'
#  '<last-active/>\n'
#  '<protocol-name>LDP</protocol-name>\n'
#  '<preference>9</preference>\n'
#  '<age seconds="2655">00:44:15</age>\n'
#  '<metric>1</metric>\n'
#  '<nh>\n'
#  '<selected-next-hop/>\n'
#  '<to>192.168.12.2</to>\n'
#  '<via>ge-0/0/0.0</via>\n'
#  '</nh>\n'
#  '</rt-entry>\n'
#  '</rt>\n'
#  '</route-table>\n'
#  '<route-table>\n'
#  '<table-name>mpls.0</table-name>\n'
#  '<destination-count>8</destination-count>\n'
#  '<total-route-count>8</total-route-count>\n'
#  '<active-route-count>8</active-route-count>\n'
#  '<holddown-route-count>0</holddown-route-count>\n'
#  '<hidden-route-count>0</hidden-route-count>\n'
#  '<rt style="brief">\n'
#  '<rt-destination>0</rt-destination>\n'
#  '<rt-entry>\n'
#  '<active-tag>*</active-tag>\n'
#  '<current-active/>\n'
#  '<last-active/>\n'
#  '<protocol-name>MPLS</protocol-name>\n'
#  '<preference>0</preference>\n'
#  '<age seconds="40599">11:16:39</age>\n'
#  '<metric>1</metric>\n'
#  '<nh>\n'
#  '<nh-table>inet.0</nh-table>\n'
#  '</nh>\n'
#  '</rt-entry>\n'
#  '</rt>\n'
#  '<rt style="brief">\n'
#  '<rt-destination>0(S=0)</rt-destination>\n'
#  '<rt-entry>\n'
#  '<active-tag>*</active-tag>\n'
#  '<current-active/>\n'
#  '<last-active/>\n'
#  '<protocol-name>MPLS</protocol-name>\n'
#  '<preference>0</preference>\n'
#  '<age seconds="40599">11:16:39</age>\n'
#  '<metric>1</metric>\n'
#  '<nh>\n'
#  '<nh-table>mpls.0</nh-table>\n'
#  '</nh>\n'
#  '</rt-entry>\n'
#  '</rt>\n'
#  '<rt style="brief">\n'
#  '<rt-destination>1</rt-destination>\n'
#  '<rt-entry>\n'
#  '<active-tag>*</active-tag>\n'
#  '<current-active/>\n'
#  '<last-active/>\n'
#  '<protocol-name>MPLS</protocol-name>\n'
#  '<preference>0</preference>\n'
#  '<age seconds="40599">11:16:39</age>\n'
#  '<metric>1</metric>\n'
#  '<nh-type>Receive</nh-type>\n'
#  '</rt-entry>\n'
#  '</rt>\n'
#  '<rt style="brief">\n'
#  '<rt-destination>2</rt-destination>\n'
#  '<rt-entry>\n'
#  '<active-tag>*</active-tag>\n'
#  '<current-active/>\n'
#  '<last-active/>\n'
#  '<protocol-name>MPLS</protocol-name>\n'
#  '<preference>0</preference>\n'
#  '<age seconds="40599">11:16:39</age>\n'
#  '<metric>1</metric>\n'
#  '<nh>\n'
#  '<nh-table>inet6.0</nh-table>\n'
#  '</nh>\n'
#  '</rt-entry>\n'
#  '</rt>\n'
#  '<rt style="brief">\n'
#  '<rt-destination>2(S=0)</rt-destination>\n'
#  '<rt-entry>\n'
#  '<active-tag>*</active-tag>\n'
#  '<current-active/>\n'
#  '<last-active/>\n'
#  '<protocol-name>MPLS</protocol-name>\n'
#  '<preference>0</preference>\n'
#  '<age seconds="40599">11:16:39</age>\n'
#  '<metric>1</metric>\n'
#  '<nh>\n'
#  '<nh-table>mpls.0</nh-table>\n'
#  '</nh>\n'
#  '</rt-entry>\n'
#  '</rt>\n'
#  '<rt style="brief">\n'
#  '<rt-destination>13</rt-destination>\n'
#  '<rt-entry>\n'
#  '<active-tag>*</active-tag>\n'
#  '<current-active/>\n'
#  '<last-active/>\n'
#  '<protocol-name>MPLS</protocol-name>\n'
#  '<preference>0</preference>\n'
#  '<age seconds="40599">11:16:39</age>\n'
#  '<metric>1</metric>\n'
#  '<nh-type>Receive</nh-type>\n'
#  '</rt-entry>\n'
#  '</rt>\n'
#  '<rt style="brief">\n'
#  '<rt-destination>299808</rt-destination>\n'
#  '<rt-entry>\n'
#  '<active-tag>*</active-tag>\n'
#  '<current-active/>\n'
#  '<last-active/>\n'
#  '<protocol-name>LDP</protocol-name>\n'
#  '<preference>9</preference>\n'
#  '<age seconds="2655">00:44:15</age>\n'
#  '<metric>1</metric>\n'
#  '<nh>\n'
#  '<selected-next-hop/>\n'
#  '<to>192.168.12.2</to>\n'
#  '<via>ge-0/0/0.0</via>\n'
#  '<mpls-label>Pop      </mpls-label>\n'
#  '</nh>\n'
#  '</rt-entry>\n'
#  '</rt>\n'
#  '<rt style="brief">\n'
#  '<rt-destination>299808(S=0)</rt-destination>\n'
#  '<rt-entry>\n'
#  '<active-tag>*</active-tag>\n'
#  '<current-active/>\n'
#  '<last-active/>\n'
#  '<protocol-name>LDP</protocol-name>\n'
#  '<preference>9</preference>\n'
#  '<age seconds="2655">00:44:15</age>\n'
#  '<metric>1</metric>\n'
#  '<nh>\n'
#  '<selected-next-hop/>\n'
#  '<to>192.168.12.2</to>\n'
#  '<via>ge-0/0/0.0</via>\n'
#  '<mpls-label>Pop      </mpls-label>\n'
#  '</nh>\n'
#  '</rt-entry>\n'
#  '</rt>\n'
#  '</route-table>\n'
#  '</route-information>\n'
#  '\n')
# <software-information>
# <host-name>core1</host-name>
# <product-model>vmx</product-model>
# <product-name>vmx</product-name>
# <junos-version>15.1F5.15</junos-version>
# <package-information>
# <name>junos</name>
# <comment>JUNOS Base OS boot [15.1F5.15]</comment>
# </package-information>
# <package-information>
# <name>jbase</name>
# <comment>JUNOS Base OS Software Suite [15.1F5.15]</comment>
# </package-information>
# <package-information>
# <name>jcrypto64</name>
# <comment>JUNOS Crypto Software Suite [15.1F5.15]</comment>
# </package-information>
# <package-information>
# <name>jdocs</name>
# <comment>JUNOS Online Documentation [15.1F5.15]</comment>
# </package-information>
# <package-information>
# <name>jplatform</name>
# <comment>JUNOS platform Software Suite [15.1F5.15]</comment>
# </package-information>
# <package-information>
# <name>jkernel</name>
# <comment>JUNOS 64-bit Kernel Software Suite [15.1F5.15]</comment>
# </package-information>
# <package-information>
# <name>jroute</name>
# <comment>JUNOS Routing Software Suite [15.1F5.15]</comment>
# </package-information>
# <package-information>
# <name>jruntime</name>
# <comment>JUNOS Runtime Software Suite [15.1F5.15]</comment>
# </package-information>
# <package-information>
# <name>jruntime64</name>
# <comment>JUNOS 64-bit Runtime Software Suite [15.1F5.15]</comment>
# </package-information>
# <package-information>
# <name>jservices-alg-pic</name>
# <comment>JUNOS Services Application Level Gateway [15.1F5.15]</comment>
# </package-information>
# <package-information>
# <name>jservices-aacl-pic</name>
# <comment>JUNOS Services AACL PIC package [15.1F5.15]</comment>
# </package-information>
# <package-information>
# <name>jservices-appid-pic</name>
# <comment>JUNOS AppId Services PIC Package [15.1F5.15]</comment>
# </package-information>
# <package-information>
# <name>jservices-alg-xlr64</name>
# <comment>JUNOS Services Application Level Gateway (xlr64) [15.1F5.15]</comment>
# </package-information>
# <package-information>
# <name>jservices-alg-xlp64</name>
# <comment>JUNOS Services Application Level Gateway (xlp64) [15.1F5.15]</comment>
# </package-information>
# <package-information>
# <name>jservices-appid-xlr64</name>
# <comment>JUNOS Services AppId PIC package (xlr64) [15.1F5.15]</comment>
# </package-information>
# <package-information>
# <name>jservices-cos-xlp64</name>
# <comment>JUNOS Services COS PIC package (xlp64) [15.1F5.15]</comment>
# </package-information>
# <package-information>
# <name>jservices-cos-pic</name>
# <comment>JUNOS Services COS PIC package [15.1F5.15]</comment>
# </package-information>
# <package-information>
# <name>jservices-bgf-pic</name>
# <comment>JUNOS Border Gateway Function PIC package [15.1F5.15]</comment>
# </package-information>
# <package-information>
# <name>jservices-hcm-pic</name>
# <comment>JUNOS Services HTTP Content Management PIC package [15.1F5.15]</comment>
# </package-information>
# <package-information>
# <name>jservices-cpcd-xlp64</name>
# <comment>JUNOS Services Captive Portal and Content Delivery (xlp64) [15.1F5.15]</comment>
# </package-information>
# <package-information>
# <name>jservices-cpcd-pic</name>
# <comment>JUNOS Services Captive Portal and Content Delivery PIC package [15.1F5.15]</comment>
# </package-information>
# <package-information>
# <name>jservices-jflow-pic</name>
# <comment>JUNOS Services JFLOW PIC package [15.1F5.15]</comment>
# </package-information>
# <package-information>
# <name>jservices-idp-pic</name>
# <comment>JUNOS IDP Services PIC Package [15.1F5.15]</comment>
# </package-information>
# <package-information>
# <name>jservices-hcm-xlr64</name>
# <comment>JUNOS Services HTTP Content Management PIC package (xlr64) [15.1F5.15]</comment>
# </package-information>
# <package-information>
# <name>jservices-llpdf-pic</name>
# <comment>JUNOS Services LL-PDF PIC package [15.1F5.15]</comment>
# </package-information>
# <package-information>
# <name>jservices-jflow-xlp64</name>
# <comment>JUNOS Services JFLOW PIC package (xlp64) [15.1F5.15]</comment>
# </package-information>
# <package-information>
# <name>jservices-mobile-pic</name>
# <comment>JUNOS MobileNext PIC package [15.1F5.15]</comment>
# </package-information>
# <package-information>
# <name>jservices-mobile-xlr64</name>
# <comment>JUNOS MobileNext PIC package (xlr64) [15.1F5.15]</comment>
# </package-information>
# <package-information>
# <name>jservices-nat-xlp64</name>
# <comment>JUNOS Services NAT PIC package (xlp64) [15.1F5.15]</comment>
# </package-information>
# <package-information>
# <name>jservices-nat-pic</name>
# <comment>JUNOS Services NAT PIC package [15.1F5.15]</comment>
# </package-information>
# <package-information>
# <name>jservices-mss-xlr64</name>
# <comment>JUNOS Services Mobile Subscriber Service PIC package (xlr64) [15.1F5.15]</comment>
# </package-information>
# <package-information>
# <name>jservices-mss-xlr</name>
# <comment>JUNOS Services Mobile Subscriber Service Container package [15.1F5.15]</comment>
# </package-information>
# <package-information>
# <name>jservices-rpm-pic</name>
# <comment>JUNOS Services RPM PIC package [15.1F5.15]</comment>
# </package-information>
# <package-information>
# <name>jservices-ptsp-pic</name>
# <comment>JUNOS Services PTSP PIC package [15.1F5.15]</comment>
# </package-information>
# <package-information>
# <name>jservices-nat-xlr64</name>
# <comment>JUNOS Services NAT PIC package (xlr64) [15.1F5.15]</comment>
# </package-information>
# <package-information>
# <name>jservices-sfw-xlr64</name>
# <comment>JUNOS Services Stateful Firewall PIC package (xlr64) [15.1F5.15]</comment>
# </package-information>
# <package-information>
# <name>jservices-sfw-xlp64</name>
# <comment>JUNOS Services Stateful Firewall PIC package (xlp64) [15.1F5.15]</comment>
# </package-information>
# <package-information>
# <name>jservices-sfw-pic</name>
# <comment>JUNOS Services Stateful Firewall PIC package [15.1F5.15]</comment>
# </package-information>
# <package-information>
# <name>jservices-rpm-xlp64</name>
# <comment>JUNOS Services RPM PIC package (xlp64) [15.1F5.15]</comment>
# </package-information>
# <package-information>
# <name>jservices-voice-bsg</name>
# <comment>JUNOS BSG PIC package [15.1F5.15]</comment>
# </package-information>
# <package-information>
# <name>jservices-crypto-base-xlr64</name>
# <comment>JUNOS Services Crypto Base PIC package(xlr64) [15.1F5.15]</comment>
# </package-information>
# <package-information>
# <name>jservices-crypto-base-xlp64</name>
# <comment>JUNOS Services Crypto Base PIC package [15.1F5.15]</comment>
# </package-information>
# <package-information>
# <name>jservices-crypto-base-pic</name>
# <comment>JUNOS Services Crypto Base PIC package [15.1F5.15]</comment>
# </package-information>
# <package-information>
# <name>jservices-ipsec-xlp64</name>
# <comment>JUNOS Services IPSec PIC package [15.1F5.15]</comment>
# </package-information>
# <package-information>
# <name>jservices-ipsec-pic</name>
# <comment>JUNOS Services IPSec PIC package [15.1F5.15]</comment>
# </package-information>
# <package-information>
# <name>jservices-ssl-pic</name>
# <comment>JUNOS Services SSL PIC package [15.1F5.15]</comment>
# </package-information>
# <package-information>
# <name>jservices-ipsec-xlr64</name>
# <comment>JUNOS Services IPSec PIC(xlr64) package [15.1F5.15]</comment>
# </package-information>
# <package-information>
# <name>jsim-pfe</name>
# <comment>JUNOS Packet Forwarding Engine Simulation Package [15.1F5.15]</comment>
# </package-information>
# </software-information>

# %%
hostname = sw.xpath("host-name")[0].text
ver = sw.xpath("junos-version")[0].text
print("%s is with software release - %s" % (hostname, ver))

print('\nall routes in inet0')
all_routes = rt.xpath("./route-table/rt")

for r in rt.xpath("./route-table/rt"):
    print(r.findtext('./rt-destination'), r.findtext('./rt-entry/nh/to'))
# Out:
# core1 is with software release - 15.1F5.15
#
# all routes in inet0
# 0.0.0.0/0 172.17.0.1
# 1.1.1.1/32 None
# 2.2.2.2/32 192.168.12.2
# 172.17.0.0/24 None
# 172.17.0.101/32 None
# 192.168.12.0/24 None
# 192.168.12.1/32 None
# 222.2.2.0/24 None
# 222.2.2.2/32 None
# 224.0.0.2/32 None
# 224.0.0.5/32 None
# 2.2.2.2/32 192.168.12.2
# 0 None
# 0(S=0) None
# 1 None
# 2 None
# 2(S=0) None
# 13 None
# 299808 192.168.12.2
# 299808(S=0) 192.168.12.2

# %%
import jinja2, yaml
templateLoader = jinja2.FileSystemLoader(searchpath=".")
templateEnv = jinja2.Environment(loader=templateLoader, autoescape=False, trim_blocks=False)

config_vars = {
          'interfaces' : [
             { 'physical_interface' : 'ge-0/0/4', 'description' : 'this is ge-0/0/4', 'ip_address' : '10.10.10.1/24' } ,
             { 'physical_interface' : 'ge-0/0/5', 'description' : 'this is ge-0/0/5', 'ip_address' : '10.10.30.1/24' }
           ]
}

TEMPLATE_FILE = 'interface.j2'
template = templateEnv.get_template(TEMPLATE_FILE)
outputText = template.render(config_vars)
print(outputText)
# Out:
# interfaces {
#
#     ge-0/0/4 {
#         description "this is ge-0/0/4";
#         unit 0 {
#
#             family inet {
#                 address "10.10.10.1/24";
#         }
#
#         }
#     }
#     ge-0/0/5 {
#         description "this is ge-0/0/5";
#         unit 0 {
#
#             family inet {
#                 address "10.10.30.1/24";
#         }
#
#         }
#     }
# }

# %%
# with Config(dev, mode='private') as cu:
with Config(dev) as cu: 
    cu.load(outputText, format="text", merge=True)
    cu.pdiff()

#     cu.commit(comment='rendered configuration')
# Out:
# [edit interfaces]
# +   ge-0/0/4 {
# +       description "this is ge-0/0/4";
# +       unit 0 {
# +           family inet {
# +               address 10.10.10.1/24;
# +           }
# +       }
# +   }
# +   ge-0/0/5 {
# +       description "this is ge-0/0/5";
# +       unit 0 {
# +           family inet {
# +               address 10.10.30.1/24;
# +           }
# +       }
# +   }

# %%
    cu.rollback()
# Out:
# True

# %%
dev.close()
